# %% [markdown]
# ## COVID - ANALYSIS project - 7

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Dell\OneDrive\Desktop\Data-Science-Specialization-main\Week - 8\Projects\country_vaccinations.csv")
df
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
df['total_vaccinations'].fillna(0,inplace = True)

# %%
df.isna().sum()
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                         0
# people_vaccinated                      45218
# people_fully_vaccinated                47710
# daily_vaccinations_raw                 51150
# daily_vaccinations                       299
# total_vaccinations_per_hundred         42905
# people_vaccinated_per_hundred          45218
# people_fully_vaccinated_per_hundred    47710
# daily_vaccinations_per_million           299
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
df['people_vaccinated'].fillna(0,inplace = True)

# %% [markdown]
# ### how many people are total vaccinated in India in may 2021

# %%
# 1st approach:
filtered_df = df[(df['country'] == 'India') &  (df['date'].str.startswith('2021-05'))]
total_vaccinated = filtered_df['total_vaccinations'].sum()
print(total_vaccinated)
# Out:
# 5432545301.0

# %%
# another approach:
india = 0
for i in range(len(df)):
    if df.loc[i, 'country'] == "India" and int(df.loc[i,'date'][:4])==2021 and int(df.loc[i,'date'][5:7]) == 5:
        
        india += (df.loc[i,'total_vaccinations'])
print(india)
# Out:
# 5432545301.0

# %% [markdown]
# ### how many people are vaccinated in albania on 2022-01-12:

# %%
for i in range(len(df)):
    if df.loc[i, 'country'] == "Albania" and (df.loc[i,'date'])=='2022-01-12' :
        print((df.loc[i,'people_vaccinated']))
# Out:
# 0.0

# %%
filtered_df = df[(df['country'] == 'Albania') & (df['date'] == '2022-01-12')]
vaccinated_count = filtered_df['people_vaccinated'].sum()
print(vaccinated_count)
# Out:
# 0.0

# %% [markdown]
# #### Analysis : people that are totally vaccinated in India in may 2021 is 5432545301.0 and people are vaccinated in albania on 2022-01-12 are 0
