# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Dell\OneDrive\Desktop\Data-Science-Specialization-main\Week - 9\Projects\country_vaccinations.csv")
df
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 86507          4814582.0                3473523.0                139213.0
# 86508          4886242.0                3487962.0                100086.0
# 86509          4918147.0                3493763.0                 53311.0
# 86510          4975433.0                3501493.0                 89321.0
# 86511          5053114.0                3510256.0                105369.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 86507             69579.0                           57.59
# 86508             83429.0                           58.25
# 86509             90629.0                           58.61
# 86510            100614.0                           59.20
# 86511            103751.0                           59.90
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 86507                          31.90                                23.02
# 86508                          32.38                                23.11
# 86509                          32.59                                23.15
# 86510                          32.97                                23.20
# 86511                          33.48                                23.26
#
#        daily_vaccinations_per_million  \
# 0                                 NaN
# 1                                34.0
# 2                                34.0
# 3                                34.0
# 4                                34.0
# ...                               ...
# 86507                          4610.0
# 86508                          5528.0
# 86509                          6005.0
# 86510                          6667.0
# 86511                          6874.0
#
#                                                 vaccines  \
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...                                                  ...
# 86507  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86508  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86509  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86510  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86511  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 0      World Health Organization
# 1      World Health Organization
# 2      World Health Organization
# 3      World Health Organization
# 4      World Health Organization
# ...                          ...
# 86507         Ministry of Health
# 86508         Ministry of Health
# 86509         Ministry of Health
# 86510         Ministry of Health
# 86511         Ministry of Health
#
#                                           source_website
# 0                               https://covid19.who.int/
# 1                               https://covid19.who.int/
# 2                               https://covid19.who.int/
# 3                               https://covid19.who.int/
# 4                               https://covid19.who.int/
# ...                                                  ...
# 86507  https://www.arcgis.com/home/webmap/viewer.html...
# 86508  https://www.arcgis.com/home/webmap/viewer.html...
# 86509  https://www.arcgis.com/home/webmap/viewer.html...
# 86510  https://www.arcgis.com/home/webmap/viewer.html...
# 86511  https://www.arcgis.com/home/webmap/viewer.html...
#
# [86512 rows x 15 columns]

# %%
dfna = df.dropna()
dfna.isnull().sum()
# Out:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %% [markdown]
# ### Montly number of total vaccinations from jan-dec in the year 2021

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021')]
df_filtered
# Out:
#            country iso_code        date  total_vaccinations  \
# 94     Afghanistan      AFG  2021-05-27            593313.0
# 101    Afghanistan      AFG  2021-06-03            630305.0
# 433        Albania      ALB  2021-02-18              3049.0
# 515        Albania      ALB  2021-05-11            622507.0
# 516        Albania      ALB  2021-05-12            632676.0
# ...            ...      ...         ...                 ...
# 86417     Zimbabwe      ZWE  2021-12-25           7209049.0
# 86418     Zimbabwe      ZWE  2021-12-26           7214640.0
# 86419     Zimbabwe      ZWE  2021-12-27           7222381.0
# 86420     Zimbabwe      ZWE  2021-12-28           7226334.0
# 86421     Zimbabwe      ZWE  2021-12-29           7238939.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 94              479574.0                 113739.0                  2859.0
# 101             481800.0                 148505.0                  4015.0
# 433               2438.0                    611.0                  1348.0
# 515             440921.0                 181586.0                  9548.0
# 516             444755.0                 187921.0                 10169.0
# ...                  ...                      ...                     ...
# 86417          4100069.0                3108980.0                  8273.0
# 86418          4103288.0                3111352.0                  5591.0
# 86419          4105296.0                3113142.0                  7741.0
# 86420          4107151.0                3115190.0                  3953.0
# 86421          4112517.0                3121776.0                 12605.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 94                 6487.0                            1.49
# 101                5285.0                            1.58
# 433                 254.0                            0.11
# 515               12160.0                           21.67
# 516               10870.0                           22.02
# ...                   ...                             ...
# 86417             13872.0                           47.77
# 86418             12994.0                           47.80
# 86419             12481.0                           47.86
# 86420             10627.0                           47.88
# 86421             10190.0                           47.96
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 94                              1.20                                 0.29
# 101                             1.21                                 0.37
# 433                             0.08                                 0.02
# 515                            15.35                                 6.32
# 516                            15.48                                 6.54
# ...                              ...                                  ...
# 86417                          27.17                                20.60
# 86418                          27.19                                20.62
# 86419                          27.20                                20.63
# 86420                          27.21                                20.64
# 86421                          27.25                                20.68
#
#        daily_vaccinations_per_million  \
# 94                              163.0
# 101                             133.0
# 433                              88.0
# 515                            4233.0
# 516                            3784.0
# ...                               ...
# 86417                           919.0
# 86418                           861.0
# 86419                           827.0
# 86420                           704.0
# 86421                           675.0
#
#                                                 vaccines  \
# 94     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 101    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 433    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 515    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 516    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# ...                                                  ...
# 86417  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86418  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86419  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86420  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 86421  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                      source_name  \
# 94     World Health Organization
# 101    World Health Organization
# 433           Ministry of Health
# 515           Ministry of Health
# 516           Ministry of Health
# ...                          ...
# 86417         Ministry of Health
# 86418         Ministry of Health
# 86419         Ministry of Health
# 86420         Ministry of Health
# 86421         Ministry of Health
#
#                                           source_website
# 94                              https://covid19.who.int/
# 101                             https://covid19.who.int/
# 433    https://shendetesia.gov.al/vaksinimi-anticovid...
# 515    https://shendetesia.gov.al/vaksinimi-anticovid...
# 516    https://shendetesia.gov.al/vaksinimi-anticovid...
# ...                                                  ...
# 86417  https://www.arcgis.com/home/webmap/viewer.html...
# 86418  https://www.arcgis.com/home/webmap/viewer.html...
# 86419  https://www.arcgis.com/home/webmap/viewer.html...
# 86420  https://www.arcgis.com/home/webmap/viewer.html...
# 86421  https://www.arcgis.com/home/webmap/viewer.html...
#
# [24878 rows x 15 columns]

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-01')]
print("jan : ",df_filtered['total_vaccinations'].sum())
# Out:
# jan :  1137932000.0

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-02')]
print("feb : ",df_filtered['total_vaccinations'].sum())
# Out:
# feb :  4021300388.0

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-03')]
print("march : ",df_filtered['total_vaccinations'].sum())
# Out:
# march :  10542733392.0

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-04')]
print("apri : ",df_filtered['total_vaccinations'].sum())
# Out:
# apri :  19699996461.0

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-05')]
print("may : ",df_filtered['total_vaccinations'].sum())
# Out:
# may :  31736246143.0

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-06')]
print("june : ",df_filtered['total_vaccinations'].sum())
# Out:
# june :  44355139362.0

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-07')]
print("july : ",df_filtered['total_vaccinations'].sum())
# Out:
# july :  60594470534.0

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-08')]
print("aug : ",df_filtered['total_vaccinations'].sum())
# Out:
# aug :  78662644326.0

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-09')]
print("sep : ",df_filtered['total_vaccinations'].sum())
# Out:
# sep :  98931099432.0

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-10')]
print("oct : ",df_filtered['total_vaccinations'].sum())
# Out:
# oct :  110493873823.0

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-11')]
print("nov : ",df_filtered['total_vaccinations'].sum())
# Out:
# nov :  124433009695.0

# %%
df_filtered = dfna[dfna['date'].str.startswith('2021-12')]
print("dec : ",df_filtered['total_vaccinations'].sum())
# Out:
# dec :  139866584933.0
